# %% [markdown]
# # COVID screening lab simulation

# %% [markdown]
# ## Requirements and module imports
#
# Code in this simulation uses a standard Anaconda Python environment (https://www.anaconda.com/distribution/#download-section). Additionally this model uses SimPy3 (https://simpy.readthedocs.io/en/latest/). Install SimPy3 with `pip install 'simpy<4'`.

# %%
import simpy
import inspect
from sim_utils.replication import Replicator
from sim_utils.parameters import Scenario

# %% [markdown]
# ## Set up scenarios
#
# Parameters defined in scenarios will overwrite default values in the parameters python file.

# %%
# Set up a dictionary to hold scenarios
scenarios = {}

scenarios['workstations_only'] = Scenario(

    samples_per_day = 30132,
    
    basic_batch_size = 93,

    resource_numbers = {
            'human_sample_receipt': 99,
            'human_sample_prep': 99,
            'human_rna_prep': 99,
            'human_pcr': 99,
            'sample_heat_block': 99,
            'beckman_rna_extraction': 99,
            'pcr_plate_stamper': 99,
            'pcr_plate_reader': 99,
            'sample_prep_automation': 99
            },
    
    # Workstations represent the physical capacity (max jobs)
    # 7 auto sample prep or 16 manual
    workstation_capacity =  {
            'workstation_0': 99999,
            'workstation_1a': 8,
            'workstation_1b_man': 9,
            'workstation_1b_auto': 3, 
            'workstation_1c': 99, 
            'workstation_2': 16,
            'workstation_3': 4,
            'workstation_4': 13
            },

    # Resource available hours (use hours)
    resource_shift_hours =  {
            'human_sample_receipt': (0.3, 17.75),
            'human_sample_prep': (0.3, 17.75),
            'human_rna_prep': (0.3, 17.75),
            'human_pcr': (0.3, 17.75),
            'sample_heat_block': (0.0, 24.0),
            'beckman_rna_extraction': (0.0, 24.0),
            'pcr_plate_stamper': (0.0, 24.0),
            'pcr_plate_reader': (0.0, 24.0),
            'sample_prep_automation': (0.0, 24.0),
            },
    
    # FTE should always be present for start times
    process_start_hours = {
            'sample_receipt': (0., 15.5),
            'sample_prep': (0., 15.5),
            'sample_heat': (0., 15.5),
            'rna_extraction': (0., 24),
            'pcr_prep': (0., 24),
            'pcr': (0.3, 24)
            },
    
    # Process duration. Tuple of fixed time, time per entity, and time per item in entity.
    # Multi-step automated processes have three sets of times (set up, automated, clean down)
    process_duration = {
             'batch_input': ([0,0,0],),
             'sample_receipt': ([16, 0, 0],),
             'sample_prep_manual': ([37, 0, 0],),
             'sample_prep_auto': ([2, 0, 0], [6, 0, 0], [8, 0, 0]),
             'sample_heat':  ([1, 0, 0], [20, 0, 0], [2, 0, 0]),
             'rna_extraction': ([15,0,0],[77,0,0],[5,0,0]),
             'pcr_prep': ([31,0,0],[10,0,0],[1,0,0]),
             'pcr': ([5,0,0],[117,0,0],[1,0,0]),
             'data_analysis': ([0,0,0],)
             },
    
    # Resource unavailability on any whole day due to breakdown
    resource_breakdown_unavailability = {
            'human_sample_receipt': 0,
            'human_sample_prep': 0,
            'human_rna_prep': 0,
            'human_pcr': 0,
            'sample_heat_block': 0,
            'beckman_rna_extraction': 0.0,
            'pcr_plate_stamper': 0.0,
            'pcr_plate_reader': 0.0,
            'sample_prep_automation': 0
            },
    
              
    allow_maual_sample_prep = True,
    tea_break_times = [2*60, 7*60, 12*60, 16*60],
    meal_break_times = [4*60, 14*60],
    break_start_spread = 60,
    tea_break_duration = [1,1] ,#[25, 35],
    meal_break_duration = [1,1] #[40, 50]
    )
  
scenarios['equipment_no_breakdown'] = Scenario(

    samples_per_day = 30132,
    
    basic_batch_size = 93,

    resource_numbers = {
            'human_sample_receipt': 99,
            'human_sample_prep': 99,
            'human_rna_prep': 99,
            'human_pcr': 99,
            'sample_heat_block': 15,
            'beckman_rna_extraction': 16,
            'pcr_plate_stamper': 4,
            'pcr_plate_reader': 16,
            'sample_prep_automation': 3
            },
    
    # Workstations represent the physical capacity (max jobs)
    # 7 auto sample prep or 16 manual (or combos thereof) for 30k
    workstation_capacity =  {
            'workstation_0': 99999,
            'workstation_1a': 8,
            'workstation_1b_man': 9,
            'workstation_1b_auto': 3, 
            'workstation_1c': 15, 
            'workstation_2': 16,
            'workstation_3': 4,
            'workstation_4': 13
            },

    # Resource available hours (use hours)
    resource_shift_hours =  {
            'human_sample_receipt': (0.3, 17.75),
            'human_sample_prep': (0.3, 17.75),
            'human_rna_prep': (0.3, 17.75),
            'human_pcr': (0.3, 17.75),
            'sample_heat_block': (0.0, 24.0),
            'beckman_rna_extraction': (0.0, 24.0),
            'pcr_plate_stamper': (0.0, 24.0),
            'pcr_plate_reader': (0.0, 24.0),
            'sample_prep_automation': (0.0, 24.0),
            },
    
    # FTE should always be present for start times
    process_start_hours = {
            'sample_receipt': (0., 15.5),
            'sample_prep': (0., 15.5),
            'sample_heat': (0., 15.5),
            'rna_extraction': (0., 24),
            'pcr_prep': (0., 24),
            'pcr': (0.3, 24)
            },
    
    # Process duration. Tuple of fixed time, time per entity, and time per item in entity.
    # Multi-step automated processes have three sets of times (set up, automated, clean down)
    process_duration = {
             'batch_input': ([0,0,0],),
             'sample_receipt': ([16, 0, 0],),
             'sample_prep_manual': ([37, 0, 0],),
             'sample_prep_auto': ([2, 0, 0], [6, 0, 0], [8, 0, 0]),
             'sample_heat':  ([1, 0, 0], [20, 0, 0], [2, 0, 0]),
             'rna_extraction': ([15,0,0],[77,0,0],[5,0,0]),
             'pcr_prep': ([31,0,0],[10,0,0],[1,0,0]),
             'pcr': ([5,0,0],[117,0,0],[1,0,0]),
             'data_analysis': ([0,0,0],)
             },
    
    # Resource unavailability on any whole day due to breakdown
    resource_breakdown_unavailability = {
            'human_sample_receipt': 0,
            'human_sample_prep': 0,
            'human_rna_prep': 0,
            'human_pcr': 0,
            'sample_heat_block': 0,
            'beckman_rna_extraction': 0.0,
            'pcr_plate_stamper': 0.0,
            'pcr_plate_reader': 0.0,
            'sample_prep_automation': 0
            },
    
              
    allow_maual_sample_prep = True,
    tea_break_times = [2*60, 7*60, 12*60, 16*60],
    meal_break_times = [4*60, 14*60],
    break_start_spread = 60,
    tea_break_duration = [1,1] ,#[25, 35],
    meal_break_duration = [1,1] #[40, 50]
    )

scenarios['equipment_with_breakdown'] = Scenario(
    

    samples_per_day = 30132,
    
    basic_batch_size = 93,

    resource_numbers = {
            'human_sample_receipt': 99,
            'human_sample_prep': 99,
            'human_rna_prep': 99,
            'human_pcr': 99,
            'sample_heat_block': 15,
            'beckman_rna_extraction': 17,
            'pcr_plate_stamper': 6,
            'pcr_plate_reader': 17,
            'sample_prep_automation': 3
            },
    
    # Workstations represent the physical capacity (max jobs)
    # 7 auto sample prep or 16 manual (or combos thereof) for 30k
    workstation_capacity =  {
            'workstation_0': 99999,
            'workstation_1a': 8,
            'workstation_1b_man': 9,
            'workstation_1b_auto': 3, 
            'workstation_1c': 15, 
            'workstation_2': 16,
            'workstation_3': 4,
            'workstation_4': 13
            },

    # Resource available hours (use hours)
    resource_shift_hours =  {
            'human_sample_receipt': (0.3, 17.75),
            'human_sample_prep': (0.3, 17.75),
            'human_rna_prep': (0.3, 17.75),
            'human_pcr': (0.3, 17.75),
            'sample_heat_block': (0.0, 24.0),
            'beckman_rna_extraction': (0.0, 24.0),
            'pcr_plate_stamper': (0.0, 24.0),
            'pcr_plate_reader': (0.0, 24.0),
            'sample_prep_automation': (0.0, 24.0),
            },
    
    # FTE should always be present for start times
    process_start_hours = {
            'sample_receipt': (0., 15.5),
            'sample_prep': (0., 15.5),
            'sample_heat': (0., 15.5),
            'rna_extraction': (0., 24),
            'pcr_prep': (0., 24),
            'pcr': (0.3, 24)
            },
    
    # Process duration. Tuple of fixed time, time per entity, and time per item in entity.
    # Multi-step automated processes have three sets of times (set up, automated, clean down)
    process_duration = {
             'batch_input': ([0,0,0],),
             'sample_receipt': ([16, 0, 0],),
             'sample_prep_manual': ([37, 0, 0],),
             'sample_prep_auto': ([2, 0, 0], [6, 0, 0], [8, 0, 0]),
             'sample_heat':  ([1, 0, 0], [20, 0, 0], [2, 0, 0]),
             'rna_extraction': ([15,0,0],[77,0,0],[5,0,0]),
             'pcr_prep': ([31,0,0],[10,0,0],[1,0,0]),
             'pcr': ([5,0,0],[117,0,0],[1,0,0]),
             'data_analysis': ([0,0,0],)
             },
    
    # Resource unavailability on any whole day due to breakdown
    resource_breakdown_unavailability = {
            'human_sample_prep': 0,
            'human_rna_prep': 0,
            'human_pcr': 0,
            'sample_heat_block': 0,
            'beckman_rna_extraction': 0.04,
            'pcr_plate_stamper': 0.08,
            'pcr_plate_reader': 0.02,
            'sample_prep_automation': 0
            },
    
              
    allow_maual_sample_prep = True,
    tea_break_times = [2*60, 7*60, 12*60, 16*60],
    meal_break_times = [4*60, 14*60],
    break_start_spread = 60,
    tea_break_duration = [1,1] ,#[25, 35],
    meal_break_duration = [1,1] #[40, 50]
    )

scenarios['fte_no_breaks'] = Scenario(
    samples_per_day = 30132,
    
    basic_batch_size = 93,

    resource_numbers = {
            'human_sample_receipt': 16,
            'human_sample_prep': 14,
            'human_rna_prep': 4,
            'human_pcr': 4,
            'sample_heat_block': 15,
            'beckman_rna_extraction': 17,
            'pcr_plate_stamper': 6,
            'pcr_plate_reader': 17,
            'sample_prep_automation': 3
            },
    
    # Workstations represent the physical capacity (max jobs)
    # 7 auto sample prep or 16 manual
    workstation_capacity =  {
            'workstation_0': 99999,
            'workstation_1a': 8,
            'workstation_1b_man': 9,
            'workstation_1b_auto': 3, 
            'workstation_1c': 15, 
            'workstation_2': 16,
            'workstation_3': 4,
            'workstation_4': 13
            },

    # Resource available hours (use hours)
    resource_shift_hours =  {
            'human_sample_receipt': (0.3, 17.75),
            'human_sample_prep': (0.3, 17.75),
            'human_rna_prep': (0.3, 17.75),
            'human_pcr': (0.3, 17.75),
            'sample_heat_block': (0.0, 24.0),
            'beckman_rna_extraction': (0.0, 24.0),
            'pcr_plate_stamper': (0.0, 24.0),
            'pcr_plate_reader': (0.0, 24.0),
            'sample_prep_automation': (0.0, 24.0),
            },
    
    # FTE should always be present for start times
    process_start_hours = {
            'sample_receipt': (0., 15.5),
            'sample_prep': (0., 15.5),
            'sample_heat': (0., 15.5),
            'rna_extraction': (0., 24),
            'pcr_prep': (0., 24),
            'pcr': (0.3, 24)
            },
    
    # Process duration. Tuple of fixed time, time per entity, and time per item in entity.
    # Multi-step automated processes have three sets of times (set up, automated, clean down)
    process_duration = {
             'batch_input': ([0,0,0],),
             'sample_receipt': ([16, 0, 0],),
             'sample_prep_manual': ([37, 0, 0],),
             'sample_prep_auto': ([2, 0, 0], [6, 0, 0], [8, 0, 0]),
             'sample_heat':  ([1, 0, 0], [20, 0, 0], [2, 0, 0]),
             'rna_extraction': ([15,0,0],[77,0,0],[5,0,0]),
             'pcr_prep': ([31,0,0],[10,0,0],[1,0,0]),
             'pcr': ([5,0,0],[117,0,0],[1,0,0]),
             'data_analysis': ([0,0,0],)
             },
    
    # Resource unavailability on any whole day due to breakdown
    resource_breakdown_unavailability = {
            'human_sample_receipt': 0,
            'human_sample_prep': 0,
            'human_rna_prep': 0,
            'human_pcr': 0,
            'sample_heat_block': 0,
            'beckman_rna_extraction': 0.04,
            'pcr_plate_stamper': 0.08,
            'pcr_plate_reader': 0.02,
            'sample_prep_automation': 0
            },
    
              
    allow_maual_sample_prep = True,
    tea_break_times = [2*60, 7*60, 12*60, 16*60],
    meal_break_times = [4*60, 14*60],
    break_start_spread = 60,
    tea_break_duration = [0,0],
    meal_break_duration = [0,0]
    )

scenarios['fte_with_breaks'] = Scenario(

    samples_per_day = 30132,
    
    basic_batch_size = 93,

    resource_numbers = {
            'human_sample_receipt': 22,
            'human_sample_prep': 18,
            'human_rna_prep': 8,
            'human_pcr': 6,
            'sample_heat_block': 15,
            'beckman_rna_extraction': 17,
            'pcr_plate_stamper': 6,
            'pcr_plate_reader': 17,
            'sample_prep_automation': 3
            },
    
    # Workstations represent the physical capacity (max jobs)
    # 7 auto sample prep or 16 manual
    workstation_capacity =  {
            'workstation_0': 99999,
            'workstation_1a': 8,
            'workstation_1b_man': 9,
            'workstation_1b_auto': 3, 
            'workstation_1c': 15, 
            'workstation_2': 16,
            'workstation_3': 4,
            'workstation_4': 13
            },

    # Resource available hours (use hours)
    resource_shift_hours =  {
            'human_sample_receipt': (0.3, 17.75),
            'human_sample_prep': (0.3, 17.75),
            'human_rna_prep': (0.3, 17.75),
            'human_pcr': (0.3, 17.75),
            'sample_heat_block': (0.0, 24.0),
            'beckman_rna_extraction': (0.0, 24.0),
            'pcr_plate_stamper': (0.0, 24.0),
            'pcr_plate_reader': (0.0, 24.0),
            'sample_prep_automation': (0.0, 24.0),
            },
    
    # FTE should always be present for start times
    process_start_hours = {
            'sample_receipt': (0., 15.5),
            'sample_prep': (0., 15.5),
            'sample_heat': (0., 15.5),
            'rna_extraction': (0., 24),
            'pcr_prep': (0., 24),
            'pcr': (0.3, 24)
            },
    
    # Process duration. Tuple of fixed time, time per entity, and time per item in entity.
    # Multi-step automated processes have three sets of times (set up, automated, clean down)
    process_duration = {
             'batch_input': ([0,0,0],),
             'sample_receipt': ([16, 0, 0],),
             'sample_prep_manual': ([37, 0, 0],),
             'sample_prep_auto': ([2, 0, 0], [6, 0, 0], [8, 0, 0]),
             'sample_heat':  ([1, 0, 0], [20, 0, 0], [2, 0, 0]),
             'rna_extraction': ([15,0,0],[77,0,0],[5,0,0]),
             'pcr_prep': ([31,0,0],[10,0,0],[1,0,0]),
             'pcr': ([5,0,0],[117,0,0],[1,0,0]),
             'data_analysis': ([0,0,0],)
             },
    
    # Resource unavailability on any whole day due to breakdown
    resource_breakdown_unavailability = {
            'human_sample_receipt': 0,
            'human_sample_prep': 0,
            'human_rna_prep': 0,
            'human_pcr': 0,
            'sample_heat_block': 0,
            'beckman_rna_extraction': 0.04,
            'pcr_plate_stamper': 0.08,
            'pcr_plate_reader': 0.02,
            'sample_prep_automation': 0
            },
    
              
    allow_maual_sample_prep = True,
    tea_break_times = [2*60, 7*60, 12*60, 16*60],
    meal_break_times = [4*60, 14*60],
    break_start_spread = 60,
    tea_break_duration = [25, 35],
    meal_break_duration = [40, 50]
    )

# %% [markdown]
# ## Run model

# %%
replications = 30
replications = Replicator(scenarios, replications)
replications.run_scenarios()
# Out:
#
# Output results
# --------------
#                                                          min          mean  \
#                                                       Result        Result
# result_type               name
# demand_met                equipment_no_breakdown        1.00      1.000000
#                           equipment_with_breakdown      1.00      1.000000
#                           fte_no_breaks                 0.88      0.992000
#                           fte_with_breaks               0.86      0.991333
#                           workstations_only             1.00      1.000000
# input                     equipment_no_breakdown    30132.00  30132.000000
#                           equipment_with_breakdown  30132.00  30132.000000
#                           fte_no_breaks             30132.00  30132.000000
#                           fte_with_breaks           30132.00  30132.000000
#                           workstations_only         30132.00  30132.000000
# max_process_time_hours    equipment_no_breakdown       22.67     22.815000
#                           equipment_with_breakdown     22.68     23.044000
#                           fte_no_breaks                22.70     22.997333
#                           fte_with_breaks              22.57     23.090333
#                           workstations_only            22.72     22.853667
# median_process_time_hours equipment_no_breakdown       22.67     22.815000
#                           equipment_with_breakdown     22.68     23.044000
#                           fte_no_breaks                22.70     22.997333
#                           fte_with_breaks              22.57     23.090333
#                           workstations_only            22.72     22.853667
# output                    equipment_no_breakdown    30132.00  30132.000000
#                           equipment_with_breakdown  30132.00  30132.000000
#                           fte_no_breaks             26412.00  29884.000000
#                           fte_with_breaks           26040.00  29846.800000
#                           workstations_only         30132.00  30132.000000
#
#                                                        median       max
#                                                        Result    Result
# result_type               name
# demand_met                equipment_no_breakdown        1.000      1.00
#                           equipment_with_breakdown      1.000      1.00
#                           fte_no_breaks                 1.000      1.00
#                           fte_with_breaks               1.000      1.00
#                           workstations_only             1.000      1.00
# input                     equipment_no_breakdown    30132.000  30132.00
#                           equipment_with_breakdown  30132.000  30132.00
#                           fte_no_breaks             30132.000  30132.00
#                           fte_with_breaks           30132.000  30132.00
#                           workstations_only         30132.000  30132.00
# max_process_time_hours    equipment_no_breakdown       22.825     22.95
#                           equipment_with_breakdown     22.850     23.87
#                           fte_no_breaks                22.880     23.90
#                           fte_with_breaks              23.030     23.92
#                           workstations_only            22.850     23.23
# median_process_time_hours equipment_no_breakdown       22.825     22.95
#                           equipment_with_breakdown     22.850     23.87
#                           fte_no_breaks                22.880     23.90
#                           fte_with_breaks              23.030     23.92
#                           workstations_only            22.850     23.23
# output                    equipment_no_breakdown    30132.000  30132.00
#                           equipment_with_breakdown  30132.000  30132.00
#                           fte_no_breaks             30132.000  30132.00
#                           fte_with_breaks           30132.000  30132.00
#                           workstations_only         30132.000  30132.00
#
#
#
# Resources used
# --------------
#                                                  Available       Used  \
# resource               name
# beckman_rna_extraction equipment_no_breakdown           16  11.463158
#                        equipment_with_breakdown         17  12.415789
#                        fte_no_breaks                    17  12.547368
#                        fte_with_breaks                  17  11.763158
#                        workstations_only                99  11.468421
# human_pcr              equipment_no_breakdown           99   3.202899
#                        equipment_with_breakdown         99   3.188406
#                        fte_no_breaks                     4   2.623188
#                        fte_with_breaks                   6   3.775362
#                        workstations_only                99   3.210145
# human_rna_prep         equipment_no_breakdown           99   3.746377
#                        equipment_with_breakdown         99   3.688406
#                        fte_no_breaks                     4   3.094203
#                        fte_with_breaks                   8   4.666667
#                        workstations_only                99   3.746377
# human_sample_prep      equipment_no_breakdown           99   2.985507
#                        equipment_with_breakdown         99   2.898551
#                        fte_no_breaks                    14   2.355072
#                        fte_with_breaks                  18   6.021739
#                        workstations_only                99   2.956522
# human_sample_receipt   equipment_no_breakdown           99  12.789855
#                        equipment_with_breakdown         99  12.753623
#                        fte_no_breaks                    16  12.268116
#                        fte_with_breaks                  22  16.594203
#                        workstations_only                99  12.739130
# pcr_plate_reader       equipment_no_breakdown           16   7.200000
#                        equipment_with_breakdown         17   7.257895
#                        fte_no_breaks                    17   7.252632
#                        fte_with_breaks                  17   7.273684
#                        workstations_only                99   7.189474
# pcr_plate_stamper      equipment_no_breakdown            4   2.531579
#                        equipment_with_breakdown          6   2.547368
#                        fte_no_breaks                     6   2.626316
#                        fte_with_breaks                   6   2.736842
#                        workstations_only                99   2.526316
# sample_heat_block      equipment_no_breakdown           15   5.305263
#                        equipment_with_breakdown         15   5.310526
#                        fte_no_breaks                    15   5.321053
#                        fte_with_breaks                  15   5.326316
#                        workstations_only                99   5.300000
# sample_prep_automation equipment_no_breakdown            3   1.647368
#                        equipment_with_breakdown          3   1.631579
#                        fte_no_breaks                     3   1.663158
#                        fte_with_breaks                   3   1.663158
#                        workstations_only                99   1.631579
#
#                                                  Utilisation
# resource               name
# beckman_rna_extraction equipment_no_breakdown       0.716447
#                        equipment_with_breakdown     0.730341
#                        fte_no_breaks                0.738080
#                        fte_with_breaks              0.691950
#                        workstations_only            0.115843
# human_pcr              equipment_no_breakdown       0.032353
#                        equipment_with_breakdown     0.032206
#                        fte_no_breaks                0.655797
#                        fte_with_breaks              0.629227
#                        workstations_only            0.032426
# human_rna_prep         equipment_no_breakdown       0.037842
#                        equipment_with_breakdown     0.037257
#                        fte_no_breaks                0.773551
#                        fte_with_breaks              0.583333
#                        workstations_only            0.037842
# human_sample_prep      equipment_no_breakdown       0.030157
#                        equipment_with_breakdown     0.029278
#                        fte_no_breaks                0.168219
#                        fte_with_breaks              0.334541
#                        workstations_only            0.029864
# human_sample_receipt   equipment_no_breakdown       0.129190
#                        equipment_with_breakdown     0.128824
#                        fte_no_breaks                0.766757
#                        fte_with_breaks              0.754282
#                        workstations_only            0.128678
# pcr_plate_reader       equipment_no_breakdown       0.450000
#                        equipment_with_breakdown     0.426935
#                        fte_no_breaks                0.426625
#                        fte_with_breaks              0.427864
#                        workstations_only            0.072621
# pcr_plate_stamper      equipment_no_breakdown       0.632895
#                        equipment_with_breakdown     0.424561
#                        fte_no_breaks                0.437719
#                        fte_with_breaks              0.456140
#                        workstations_only            0.025518
# sample_heat_block      equipment_no_breakdown       0.353684
#                        equipment_with_breakdown     0.354035
#                        fte_no_breaks                0.354737
#                        fte_with_breaks              0.355088
#                        workstations_only            0.053535
# sample_prep_automation equipment_no_breakdown       0.549123
#                        equipment_with_breakdown     0.543860
#                        fte_no_breaks                0.554386
#                        fte_with_breaks              0.554386
#                        workstations_only            0.016481
#
#
#
# Queuing times
# -------------
#                                            median     max
# queue            name
# q_data_analysis  equipment_no_breakdown      0.50    1.00
#                  equipment_with_breakdown    0.50    1.00
#                  fte_no_breaks               0.50    1.00
#                  fte_with_breaks             0.50    1.00
#                  workstations_only           0.50    1.00
# q_pcr            equipment_no_breakdown      0.50    1.00
#                  equipment_with_breakdown    0.50    1.00
#                  fte_no_breaks               0.50    1.00
#                  fte_with_breaks             0.50    1.00
#                  workstations_only           0.50    1.00
# q_pcr_collation  equipment_no_breakdown      0.90   21.00
#                  equipment_with_breakdown    0.90   23.70
#                  fte_no_breaks               0.90   23.60
#                  fte_with_breaks             0.90   26.20
#                  workstations_only           0.90   22.80
# q_pcr_prep       equipment_no_breakdown      0.00   18.00
#                  equipment_with_breakdown    0.00   17.00
#                  fte_no_breaks               0.00    9.00
#                  fte_with_breaks             3.00   49.50
#                  workstations_only           0.00   18.50
# q_rna_collation  equipment_no_breakdown      0.70   18.40
#                  equipment_with_breakdown    0.70   18.10
#                  fte_no_breaks               0.70   18.60
#                  fte_with_breaks             0.70   19.00
#                  workstations_only           0.70   18.15
# q_rna_extraction equipment_no_breakdown     48.75  545.50
#                  equipment_with_breakdown   52.00  552.50
#                  fte_no_breaks              51.00  578.50
#                  fte_with_breaks            41.25  475.50
#                  workstations_only          48.75  564.50
# q_sample_heat    equipment_no_breakdown      0.50    1.00
#                  equipment_with_breakdown    0.50    1.00
#                  fte_no_breaks               0.50    1.00
#                  fte_with_breaks             0.50    1.00
#                  workstations_only           0.50    1.00
# q_sample_prep    equipment_no_breakdown     24.05  362.20
#                  equipment_with_breakdown   24.60  385.90
#                  fte_no_breaks              15.55  244.60
#                  fte_with_breaks             5.80  128.15
#                  workstations_only          25.25  362.20
# q_sample_receipt equipment_no_breakdown    355.50  714.00
#                  equipment_with_breakdown  354.50  713.00
#                  fte_no_breaks             374.50  762.00
#                  fte_with_breaks           420.25  835.50
#                  workstations_only         355.00  714.00
#
#
#
# Max samples queuing
# -------------------
# Results describe maximum queueing across runs
#                                                  amax percentile_95
#                                           Max samples   Max samples
# queue            name
# q_data_analysis  equipment_no_breakdown         744.0        372.00
#                  equipment_with_breakdown       744.0        744.00
#                  fte_no_breaks                  744.0        372.00
#                  fte_with_breaks                744.0        744.00
#                  workstations_only              744.0        744.00
# q_pcr            equipment_no_breakdown         372.0        372.00
#                  equipment_with_breakdown       744.0        576.60
#                  fte_no_breaks                  372.0        372.00
#                  fte_with_breaks                744.0        744.00
#                  workstations_only              372.0        372.00
# q_pcr_collation  equipment_no_breakdown         279.0        279.00
#                  equipment_with_breakdown       279.0        279.00
#                  fte_no_breaks                  279.0        279.00
#                  fte_with_breaks                372.0        372.00
#                  workstations_only              279.0        279.00
# q_pcr_prep       equipment_no_breakdown         372.0        372.00
#                  equipment_with_breakdown       372.0        372.00
#                  fte_no_breaks                  186.0        186.00
#                  fte_with_breaks               2790.0        744.00
#                  workstations_only              372.0        372.00
# q_rna_extraction equipment_no_breakdown        2976.0       2883.00
#                  equipment_with_breakdown      3627.0       3534.00
#                  fte_no_breaks                 4836.0       4115.25
#                  fte_with_breaks               3069.0       2799.30
#                  workstations_only             2976.0       2976.00
# q_sample_heat    equipment_no_breakdown         279.0        279.00
#                  equipment_with_breakdown       372.0        279.00
#                  fte_no_breaks                  279.0        279.00
#                  fte_with_breaks                279.0        279.00
#                  workstations_only              372.0        279.00
# q_sample_prep    equipment_no_breakdown        3999.0       3957.15
#                  equipment_with_breakdown      3999.0       3906.00
#                  fte_no_breaks                 2790.0       2520.30
#                  fte_with_breaks               1581.0       1488.00
#                  workstations_only             3906.0       3906.00
# q_sample_receipt equipment_no_breakdown       29388.0      29388.00
#                  equipment_with_breakdown     29388.0      29388.00
#                  fte_no_breaks                29388.0      29388.00
#                  fte_with_breaks              29388.0      29388.00
#                  workstations_only            29388.0      29388.00

# %% [markdown]
# ## Show model default parameters
#
# Run the code below to model defaults these are over-ridden by scenarios).

# %%
print(inspect.getsource(Scenario.__init__))
# Out:
#     def __init__(self, *initial_data, **kwargs):
#
#         # Set default values
#         # 16/4/2020 Adjust paramters so that day starts with FTE arrival
#
#
#         # Work arrival
#         self.samples_per_day = 30000
#         self.deliveries_per_day = 1
#         self.basic_batch_size = 93
#
#         # Day and run parameters
#         # 16/4/2020 Model is designed to run primarily in single days
#         self.day_duration = 1440
#         self.run_days = 1
#         self.warm_up_days = 0
#
#         # Breaks for people (high prority job, but does not interupt work)
#         # Times from start of FTE day (6am)
#         self.tea_break_times = [2*60, 7*60, 12*60, 16*60]
#         self.meal_break_times = [4*60, 14*60]
#         # Spread start of break for people randomly after set start times
#         self.break_start_spread = 60
#
#         # break duration is a uniform distribution between min and max
#         self.tea_break_duration = [25, 35]
#         self.meal_break_duration = [40, 50]
#
#         # Audit parameters
#         self.audit_interval = 15
#
#         # Resource numbers
#         self.resource_numbers = {
#             'human_sample_receipt': 20,
#             'human_sample_prep': 6,
#             'human_rna_prep': 8,
#             'human_pcr': 4,
#             'sample_heat_block': 14,
#             'beckman_rna_extraction': 22,
#             'pcr_plate_stamper': 5,
#             'pcr_plate_reader': 14,
#             'sample_prep_automation': 5
#             }
#
#         self.workstation_capacity =  {
#             'workstation_0': 99999,
#             'workstation_1a': 12,
#             'workstation_1b_man': 8,
#             'workstation_1b_auto': 5,
#             'workstation_1c': 14,
#             'workstation_2': 20,
#             'workstation_3': 5,
#             'workstation_4': 13
#             }
#
#         # Resource available hours (use hours)
#         self.resource_shift_hours = {
#             'human_sample_receipt': (0.3, 17.75),
#             'human_sample_prep': (0.3, 17.75),
#             'human_rna_prep': (0.3, 17.75),
#             'human_pcr': (0.3, 17.75),
#             'sample_heat_block': (0.0, 24.0),
#             'beckman_rna_extraction': (0.0, 24.0),
#             'pcr_plate_stamper': (0.0, 24.0),
#             'pcr_plate_reader': (0.0, 24.0),
#             'sample_prep_automation': (0.0, 24.0),
#             }
#
#
#         # Resource unavailability on any whole day due to breakdown
#         self.resource_breakdown_unavailability = {
#             'human_sample_receipt': 0,
#             'human_sample_prep': 0,
#             'human_rna_prep': 0,
#             'human_pcr': 0,
#             'sample_heat_block': 0,
#             'beckman_rna_extraction': 0.04,
#             'pcr_plate_stamper': 0.08,
#             'pcr_plate_reader': 0.02,
#             'sample_prep_automation': 0
#             }
#
#         # FTE resources (these will take breaks!)
#         self.fte_resources = [
#             'human_sample_receipt',
#             'human_sample_prep',
#             'human_rna_prep',
#             'human_pcr'
#             ]
#
#
#         # Process duration. Tuple of fixed time, time per entity, and time per item in entity.
#         # Multi-step automated processes have three sets of times (set up, automated, clean down)
#         self.process_duration = {
#              'batch_input': ([0,0,0],),
#              'sample_receipt': ([16, 0, 0],),
#              'sample_prep_manual': ([37, 0, 0],),
#              'sample_prep_auto': ([2, 0, 0], [6, 0, 0], [8, 0, 0]),
#              'sample_heat':  ([1, 0, 0], [20, 0, 0], [2, 0, 0]),
#              'rna_extraction': ([15,0,0],[77,0,0],[5,0,0]),
#              'pcr_prep': ([31,0,0],[10,0,0],[1,0,0]),
#              'pcr': ([5,0,0],[117,0,0],[1,0,0]),
#              'data_analysis': ([0,0,0],)
#              }
#
#         self.allow_maual_sample_prep = False
#
#         # Add a triangular distribution of extra time per prcoess
#         # Average extra time with be 1/4 of this (e.g. 0.25 = 6.25% added length on average)
#         self.additional_time_manual = 0.25
#         self.additional_time_auto = 0.10
#
#         # Range of times new jobs may start
#         self.process_start_hours = {
#             'sample_receipt': (0.3, 15.5),
#             'sample_prep': (0.3, 15.5),
#             'sample_heat': (0.3, 15.5),
#             'rna_extraction': (0.3, 24),
#             'pcr_prep': (0.3, 24),
#             'pcr': (0.3, 24)
#             }
#
#         # Process priories (lower number - higher prioirity)
#         self.process_priorites = {
#             'sample_receipt': 100,
#             'sample_prep_manual': 80,
#             'sample_prep_auto': 70,
#             'sample_heat': 60,
#             'rna_extraction': 40,
#             'pcr_prep': 35,
#             'pcr': 30
#             }
#
#         # Process resources = tuple of different resources needed and lists of alternatives
#         # Remember to put , after a single list to miantain tuple format!
#         # A tuple of two or more elemnts will require resources from each tuple element
#         self.process_resources = {
#             'sample_receipt': {
#                 'process_type': 'manual',
#                 'human_list': (['human_sample_receipt'],),
#                 'machine_list': ([],)},
#
#             'sample_prep_manual': {
#                 'process_type': 'manual',
#                 'human_list': (['human_sample_receipt'],),
#                 'machine_list': ([],)},
#
#             'sample_prep_auto': {
#                 'process_type': 'auto',
#                 'human_list': (['human_sample_prep'],),
#                 'machine_list': (['sample_prep_automation'],)},
#
#             'sample_heat': {
#                 'process_type': 'auto',
#                 'human_list': (['human_sample_prep'],),
#                 'machine_list': (['sample_heat_block'],)},
#
#             'rna_extraction':{
#                 'process_type': 'auto',
#                 'human_list': (['human_rna_prep'],),
#                 'machine_list': (['beckman_rna_extraction'],)},
#
#             'pcr_prep':{
#                 'process_type': 'auto',
#                 'human_list': (['human_pcr'],),
#                 'machine_list': (['pcr_plate_stamper'],)},
#
#             'pcr':{
#                 'process_type': 'auto',
#                 'human_list': (['human_pcr'],),
#                 'machine_list': (['pcr_plate_reader'],)},
#             }
#
#         # Workstation (used to limit work in progress)
#
#         self.process_workstations = {
#             'data_analysis': ['workstation_0'],
#             'batch_input': ['workstation_0'],
#             'sample_receipt': ['workstation_1a'],
#             'sample_prep_manual' : ['workstation_1b_man'],
#             'sample_prep_auto' : ['workstation_1b_auto'],
#             'sample_heat': ['workstation_1c'],
#             'rna_extraction': ['workstation_2'],
#             'pcr_prep': ['workstation_3'],
#             'pcr': ['workstation_4']
#             }
#
#
#         # kanban groups have start process, end process, max samples, current samples
#         self.kanban_groups = {
#             0: ['rna_extraction',
#                 'pcr',
#                 self.resource_numbers['pcr_plate_reader'] * 372 * 999]
#                 }
#
#         #self.kanban_groups = {}
#
#
#         # Overwrite default values
#
#         for dictionary in initial_data:
#             for key in dictionary:
#                 setattr(self, key, dictionary[key])
#
#         for key in kwargs:
#             setattr(self, key, kwargs[key])
#
#         # Calculations
#
#         # Set arrival batch size and round (down) to nearest basic batch size
#         self.arrival_batch_size = self.samples_per_day / self.deliveries_per_day
#         self.arrival_batch_size = np.floor(
#             self.arrival_batch_size / self.basic_batch_size) * self.basic_batch_size
#
#         # Set interarrival time
#         self.interarrival_time = self.day_duration / self.deliveries_per_day
#
#         # Set warm up and run length
#         self.audit_warm_up = self.day_duration * self.warm_up_days
#         self.run_length = self.run_days * self.day_duration + self.audit_warm_up
#
#         # Sort priority dictionary by value
#         self.process_priorites = {key: value for key, value in sorted(
#             self.process_priorites.items(), key=lambda item: item[1])}
#
#         # Convert resource shifts to minutes, and place in new dictionary
#         self.resource_shifts = dict()
#         for resource, shift_hours in self.resource_shift_hours.items():
#             start = shift_hours[0] * 60
#             end = shift_hours[1] * 60
#             self.resource_shifts[resource] = (start, end)
#
#         # Set up kanban group counts and dictionaries for start.end
#         self.kanban_group_counts = dict()
#         self.kanban_group_max = dict()
#         self.kanban_start = dict()
#         self.kanban_end = dict()
#
#         # Set up dictionaries based on process
#         for key in self.process_duration.keys():
#             self.kanban_start[key] = []
#             self.kanban_end[key] = []
#
#         # Update dictionaries if kanban groups exist
#         if len(self.kanban_groups) > 0:
#
#             # Add process start and ends to dictionaries
#             for key, value in self.kanban_groups.items():
#                 self.kanban_start[value[0]].append(key)
#                 self.kanban_end[value[1]].append(key)
#
#             # Set up kanban group counts
#             for key, value in self.kanban_groups.items():
#                 self.kanban_group_counts[key] = 0
#                 self.kanban_group_max[key] = value[2]
